# %% [markdown]
# # 💿 Spotify Tracks
# ## 🎵 Hypothesis 2 — Explicit vs Non-Explicit and Popularity
#
# | Field         | Description |
# |---------------|-------------|
# | Author:       | Robert Steven Elliott |
# | Course:       | Code Institute – Data Analytics with AI Bootcamp |
# | Project Type: |	Hackathon 2 |
# | Date:         |	December 2025 |

# %% [markdown]
# $$
# \begin{aligned}
# H_{0} &= \text{There is no statistically significant difference in average popularity between explicit and non-explicit tracks.} \\
# H_{1} &= \text{Explicit tracks are, on average, more popular than non-explicit tracks.}
# \end{aligned}
# $$

# %% [markdown]
# ### Import Libraries

# %%
import sys
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mannwhitneyu

# %% [markdown]
# ### Project Paths

# %%
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))
DATA_DIR = PROJECT_ROOT / "data" / "clean"

INPUT_CSV = DATA_DIR / "spotify_clean.csv"

# %% [markdown]
# ### Load Custom Libraries

# %%
from utils.data_processing import load_data
from utils.visualisation import plot_violin

# %% [markdown]
# ### Load Dataset

# %%
df = load_data(INPUT_CSV)
df.head()
# Out:
#                       artists                                   name  \
# 0        sam smith;kim petras                                 unholy
# 1            bizarrap;quevedo  quevedo: bzrp music sessions, vol. 52
# 2               manuel turizo                             la bachata
# 3     david guetta;bebe rexha                               i'm good
# 4  bad bunny;chencho corleone                        me porto bonito
#
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0         100       156943     False         0.714   0.472    2    -7.375
# 1          99       198937     False         0.621   0.782    2    -5.548
# 2          98       162637     False         0.835   0.679    7    -5.329
# 3          98       175238      True         0.561   0.965    7    -3.673
# 4          97       178567      True         0.911   0.712    1    -5.105
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %% [markdown]
# ### Take Random sample

# %%
df_sample = df.sample(n=1000, random_state=42)

# %% [markdown]
# ### Statistical Analysis
# #### Mann Whitney

# %%
explicit = df[df["explicit"] == True]["popularity"]
clean = df[df["explicit"] == False]["popularity"]

stat, p = mannwhitneyu(explicit, clean, alternative="two-sided")
print(f"Mann-Whitney U p-value: {p:.4f}")
# Out:
# Mann-Whitney U p-value: 0.0000

# %% [markdown]
# #### Violin Plot

# %%
fig = plot_violin(df,
            x_col="explicit",
            y_col="popularity",
            title="Popularity Distribution by Explicit Content",
            xlabel="Explicit Content",
            ylabel="Popularity")
fig.show()

# %% [markdown]
# ### 🧪 Hypothesis Decision
# Null Hypothesis ($H_{0}$)
#
# There is no statistically significant difference in popularity between explicit and non-explicit tracks.
#
# #### Decision
#
# ❌ Reject Null Hypothesis
#
# There is a statistically significant difference in popularity between explicit and non-explicit tracks.

# %% [markdown]
# ### 🧠 Conclusion:
#
# Hypothesis 2 is supported. A Mann–Whitney U test indicates a statistically significant difference in popularity between explicit and non-explicit tracks (p < 0.001). This suggests that explicit content is associated with different popularity outcomes, potentially reflecting listener preferences or broader cultural trends. However, effect size analysis would be required to assess the practical importance of this difference.
