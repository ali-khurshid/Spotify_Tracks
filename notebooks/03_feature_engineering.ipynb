# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/clean/spotify_clean.csv')
df
# Out:
#                        artists                        name  popularity  \
# 0                  gen hoshino                      Comedy          73
# 1                 ben woodward            Ghost - Acoustic          55
# 2       ingrid michaelson;zayn              To Begin Again          57
# 3                 kina grannis  Can't Help Falling In Love          71
# 4             chord overstreet                     Hold On          82
# ...                        ...                         ...         ...
# 106943           rainy lullaby         Sleep My Little Boy          21
# 106944           rainy lullaby            Water Into Light          22
# 106945           cesária evora              Miss Perfumado          22
# 106946        michael w. smith                     Friends          41
# 106947           cesária evora                   Barbincor          22
#
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 0            230666     False         0.676  0.4610    1    -6.746     0
# 1            149610     False         0.420  0.1660    1   -17.235     1
# 2            210826     False         0.438  0.3590    0    -9.734     1
# 3            201933     False         0.266  0.0596    0   -18.515     1
# 4            198853     False         0.618  0.4430    2    -9.681     1
# ...             ...       ...           ...     ...  ...       ...   ...
# 106943       384999     False         0.172  0.2350    5   -16.393     1
# 106944       385000     False         0.174  0.1170    0   -18.318     0
# 106945       271466     False         0.629  0.3290    0   -10.895     0
# 106946       283893     False         0.587  0.5060    7   -10.889     1
# 106947       241826     False         0.526  0.4870    1   -10.204     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# 0            0.1430        0.0322          0.000001    0.3580   0.7150
# 1            0.0763        0.9240          0.000006    0.1010   0.2670
# 2            0.0557        0.2100          0.000000    0.1170   0.1200
# 3            0.0363        0.9050          0.000071    0.1320   0.1430
# 4            0.0526        0.4690          0.000000    0.0829   0.1670
# ...             ...           ...               ...       ...      ...
# 106943       0.0422        0.6400          0.928000    0.0863   0.0339
# 106944       0.0401        0.9940          0.976000    0.1050   0.0350
# 106945       0.0420        0.8670          0.000000    0.0839   0.7430
# 106946       0.0297        0.3810          0.000000    0.2700   0.4130
# 106947       0.0725        0.6810          0.000000    0.0893   0.7080
#
#           tempo  time_signature        genre
# 0        87.917               4     acoustic
# 1        77.489               4     acoustic
# 2        76.332               4     acoustic
# 3       181.740               3     acoustic
# 4       119.949               4     acoustic
# ...         ...             ...          ...
# 106943  125.995               5  world-music
# 106944   85.239               4  world-music
# 106945  132.378               4  world-music
# 106946  135.960               4  world-music
# 106947   79.198               4  world-music
#
# [106948 rows x 18 columns]

# %% [markdown]
# Split into a dataframe for clustering and a dataframe containing the metadata

# %%
df.columns.unique()
# Out:
# Index(['artists', 'name', 'popularity', 'duration_ms', 'explicit',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'genre'],
#       dtype='object')

# %%
cluster_features = ['danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

df_cluster = df[cluster_features]
df_cluster.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.676  0.4610    -6.746       0.1430        0.0322
# 1         0.420  0.1660   -17.235       0.0763        0.9240
# 2         0.438  0.3590    -9.734       0.0557        0.2100
# 3         0.266  0.0596   -18.515       0.0363        0.9050
# 4         0.618  0.4430    -9.681       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000001    0.3580    0.715   87.917
# 1          0.000006    0.1010    0.267   77.489
# 2          0.000000    0.1170    0.120   76.332
# 3          0.000071    0.1320    0.143  181.740
# 4          0.000000    0.0829    0.167  119.949

# %% [markdown]
# These features need to be scaled

# %% [markdown]
# # Engineer Features to Support Hypotheses
#
# H1 Dance–Energy Index (H1)
#
# Purpose:
# Capture “movement intensity” — upbeat dance tracks vs calm ones.

# %%
df_cluster["dance_energy_index"] = (df["danceability"] + df["energy"]) / 2
df_cluster.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.676  0.4610    -6.746       0.1430        0.0322
# 1         0.420  0.1660   -17.235       0.0763        0.9240
# 2         0.438  0.3590    -9.734       0.0557        0.2100
# 3         0.266  0.0596   -18.515       0.0363        0.9050
# 4         0.618  0.4430    -9.681       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0          0.000001    0.3580    0.715   87.917              0.5685
# 1          0.000006    0.1010    0.267   77.489              0.2930
# 2          0.000000    0.1170    0.120   76.332              0.3985
# 3          0.000071    0.1320    0.143  181.740              0.1628
# 4          0.000000    0.0829    0.167  119.949              0.5305
#
#    scoustic_profile  acoustic_profile
# 0          0.016101          0.016101
# 1          0.462003          0.462003
# 2          0.105000          0.105000
# 3          0.452535          0.452535
# 4          0.234500          0.234500

# %% [markdown]
# H2: Acoustic Profile
#
# Purpose:
# Identify acoustic / lo-fi / instrumental-leaning tracks.

# %%
df_cluster["acoustic_profile"] = (df["acousticness"] + df["instrumentalness"]) / 2
df_cluster
# Out:
#         danceability  energy  loudness  speechiness  acousticness  \
# 0              0.676  0.4610    -6.746       0.1430        0.0322
# 1              0.420  0.1660   -17.235       0.0763        0.9240
# 2              0.438  0.3590    -9.734       0.0557        0.2100
# 3              0.266  0.0596   -18.515       0.0363        0.9050
# 4              0.618  0.4430    -9.681       0.0526        0.4690
# ...              ...     ...       ...          ...           ...
# 106943         0.172  0.2350   -16.393       0.0422        0.6400
# 106944         0.174  0.1170   -18.318       0.0401        0.9940
# 106945         0.629  0.3290   -10.895       0.0420        0.8670
# 106946         0.587  0.5060   -10.889       0.0297        0.3810
# 106947         0.526  0.4870   -10.204       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0               0.000001    0.3580   0.7150   87.917              0.5685
# 1               0.000006    0.1010   0.2670   77.489              0.2930
# 2               0.000000    0.1170   0.1200   76.332              0.3985
# 3               0.000071    0.1320   0.1430  181.740              0.1628
# 4               0.000000    0.0829   0.1670  119.949              0.5305
# ...                  ...       ...      ...      ...                 ...
# 106943          0.928000    0.0863   0.0339  125.995              0.2035
# 106944          0.976000    0.1050   0.0350   85.239              0.1455
# 106945          0.000000    0.0839   0.7430  132.378              0.4790
# 106946          0.000000    0.2700   0.4130  135.960              0.5465
# 106947          0.000000    0.0893   0.7080   79.198              0.5065
#
#         scoustic_profile  acoustic_profile
# 0               0.016101          0.016101
# 1               0.462003          0.462003
# 2               0.105000          0.105000
# 3               0.452535          0.452535
# 4               0.234500          0.234500
# ...                  ...               ...
# 106943          0.784000          0.784000
# 106944          0.985000          0.985000
# 106945          0.433500          0.433500
# 106946          0.190500          0.190500
# 106947          0.340500          0.340500
#
# [106948 rows x 12 columns]

# %% [markdown]
# H4 Mood Index
#
# Purpose:
# Capture emotional feel — sad/calm vs happy/energetic.

# %%
df_cluster["mood_index"] = (df["valence"] + df["energy"]) / 2
df_cluster
# Out:
#         danceability  energy  loudness  speechiness  acousticness  \
# 0              0.676  0.4610    -6.746       0.1430        0.0322
# 1              0.420  0.1660   -17.235       0.0763        0.9240
# 2              0.438  0.3590    -9.734       0.0557        0.2100
# 3              0.266  0.0596   -18.515       0.0363        0.9050
# 4              0.618  0.4430    -9.681       0.0526        0.4690
# ...              ...     ...       ...          ...           ...
# 106943         0.172  0.2350   -16.393       0.0422        0.6400
# 106944         0.174  0.1170   -18.318       0.0401        0.9940
# 106945         0.629  0.3290   -10.895       0.0420        0.8670
# 106946         0.587  0.5060   -10.889       0.0297        0.3810
# 106947         0.526  0.4870   -10.204       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0               0.000001    0.3580   0.7150   87.917              0.5685
# 1               0.000006    0.1010   0.2670   77.489              0.2930
# 2               0.000000    0.1170   0.1200   76.332              0.3985
# 3               0.000071    0.1320   0.1430  181.740              0.1628
# 4               0.000000    0.0829   0.1670  119.949              0.5305
# ...                  ...       ...      ...      ...                 ...
# 106943          0.928000    0.0863   0.0339  125.995              0.2035
# 106944          0.976000    0.1050   0.0350   85.239              0.1455
# 106945          0.000000    0.0839   0.7430  132.378              0.4790
# 106946          0.000000    0.2700   0.4130  135.960              0.5465
# 106947          0.000000    0.0893   0.7080   79.198              0.5065
#
#         scoustic_profile  acoustic_profile  mood_index
# 0               0.016101          0.016101     0.58800
# 1               0.462003          0.462003     0.21650
# 2               0.105000          0.105000     0.23950
# 3               0.452535          0.452535     0.10130
# 4               0.234500          0.234500     0.30500
# ...                  ...               ...         ...
# 106943          0.784000          0.784000     0.13445
# 106944          0.985000          0.985000     0.07600
# 106945          0.433500          0.433500     0.53600
# 106946          0.190500          0.190500     0.45950
# 106947          0.340500          0.340500     0.59750
#
# [106948 rows x 13 columns]

# %% [markdown]
# H2 and H3:
# Vocal Presence
#
# Purpose:
# Separate instrumental tracks from vocal / rap-heavy tracks.

# %%
df_cluster["vocal_presence"] = 1 - df["instrumentalness"]
df_cluster
# Out:
#         danceability  energy  loudness  speechiness  acousticness  \
# 0              0.676  0.4610    -6.746       0.1430        0.0322
# 1              0.420  0.1660   -17.235       0.0763        0.9240
# 2              0.438  0.3590    -9.734       0.0557        0.2100
# 3              0.266  0.0596   -18.515       0.0363        0.9050
# 4              0.618  0.4430    -9.681       0.0526        0.4690
# ...              ...     ...       ...          ...           ...
# 106943         0.172  0.2350   -16.393       0.0422        0.6400
# 106944         0.174  0.1170   -18.318       0.0401        0.9940
# 106945         0.629  0.3290   -10.895       0.0420        0.8670
# 106946         0.587  0.5060   -10.889       0.0297        0.3810
# 106947         0.526  0.4870   -10.204       0.0725        0.6810
#
#         instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0               0.000001    0.3580   0.7150   87.917              0.5685
# 1               0.000006    0.1010   0.2670   77.489              0.2930
# 2               0.000000    0.1170   0.1200   76.332              0.3985
# 3               0.000071    0.1320   0.1430  181.740              0.1628
# 4               0.000000    0.0829   0.1670  119.949              0.5305
# ...                  ...       ...      ...      ...                 ...
# 106943          0.928000    0.0863   0.0339  125.995              0.2035
# 106944          0.976000    0.1050   0.0350   85.239              0.1455
# 106945          0.000000    0.0839   0.7430  132.378              0.4790
# 106946          0.000000    0.2700   0.4130  135.960              0.5465
# 106947          0.000000    0.0893   0.7080   79.198              0.5065
#
#         scoustic_profile  acoustic_profile  mood_index  vocal_presence
# 0               0.016101          0.016101     0.58800        0.999999
# 1               0.462003          0.462003     0.21650        0.999994
# 2               0.105000          0.105000     0.23950        1.000000
# 3               0.452535          0.452535     0.10130        0.999929
# 4               0.234500          0.234500     0.30500        1.000000
# ...                  ...               ...         ...             ...
# 106943          0.784000          0.784000     0.13445        0.072000
# 106944          0.985000          0.985000     0.07600        0.024000
# 106945          0.433500          0.433500     0.53600        1.000000
# 106946          0.190500          0.190500     0.45950        1.000000
# 106947          0.340500          0.340500     0.59750        1.000000
#
# [106948 rows x 14 columns]

# %% [markdown]
# We have engineered features that represent movement, mood, acoustic character, and vocal presence to support similarity-based clustering

# %%
df_cluster.describe()
# Out:
#         danceability         energy      loudness    speechiness  \
# count  106948.000000  106948.000000  106948.00000  106948.000000
# mean        0.565018       0.642839      -8.30367       0.085466
# std         0.173769       0.252462       5.06507       0.107613
# min         0.000000       0.000000     -49.53100       0.000000
# 25%         0.454000       0.471000     -10.08200       0.035900
# 50%         0.578000       0.686000      -7.05600       0.049000
# 75%         0.693000       0.856000      -5.01900       0.085000
# max         0.985000       1.000000       4.53200       0.965000
#
#         acousticness  instrumentalness       liveness        valence  \
# count  106948.000000     106948.000000  106948.000000  106948.000000
# mean        0.313760          0.163338       0.215561       0.469294
# std         0.332777          0.315018       0.192968       0.259432
# min         0.000000          0.000000       0.000000       0.000000
# 25%         0.015400          0.000000       0.098200       0.254000
# 50%         0.168000          0.000058       0.132000       0.456000
# 75%         0.596000          0.068525       0.277000       0.678000
# max         0.996000          1.000000       1.000000       0.995000
#
#                tempo  dance_energy_index  acoustic_profile     mood_index  \
# count  106948.000000       106948.000000     106948.000000  106948.000000
# mean      122.373609            0.603928          0.238549       0.556066
# std        29.943170            0.161741          0.240558       0.202749
# min         0.000000            0.000000          0.000000       0.000000
# 25%        99.798750            0.517000          0.032570       0.424500
# 50%       122.079500            0.639000          0.169696       0.574000
# 75%       140.172000            0.721500          0.388500       0.709500
# max       243.372000            0.978000          0.997500       0.986000
#
#        vocal_presence
# count   106948.000000
# mean         0.836662
# std          0.315018
# min          0.000000
# 25%          0.931475
# 50%          0.999942
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Create dataframe of metadata

# %%
metadata_cols = ['artists', 'name', 'popularity', 'duration_ms', 'explicit', 'genre']

df_metadata = df[metadata_cols]
df_metadata.head()
# Out:
#                   artists                        name  popularity  \
# 0             gen hoshino                      Comedy          73
# 1            ben woodward            Ghost - Acoustic          55
# 2  ingrid michaelson;zayn              To Begin Again          57
# 3            kina grannis  Can't Help Falling In Love          71
# 4        chord overstreet                     Hold On          82
#
#    duration_ms  explicit     genre
# 0       230666     False  acoustic
# 1       149610     False  acoustic
# 2       210826     False  acoustic
# 3       201933     False  acoustic
# 4       198853     False  acoustic
