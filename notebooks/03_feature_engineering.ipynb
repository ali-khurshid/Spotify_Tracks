# %%
import pandas as pd
import numpy as np
import sys
from pathlib import Path
import warnings
warnings.filterwarnings("ignore")

# %%
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
df = pd.read_csv(f'{PROJECT_ROOT}/data/clean/spotify_clean.csv')
df
# Out:
#                           artists                                   name  \
# 0            sam smith;kim petras                                 unholy
# 1                bizarrap;quevedo  quevedo: bzrp music sessions, vol. 52
# 2                   manuel turizo                             la bachata
# 3         david guetta;bebe rexha                               i'm good
# 4      bad bunny;chencho corleone                        me porto bonito
# ...                           ...                                    ...
# 77503                    lil baby                            in a minute
# 77504         future;lil uzi vert                                tic tac
# 77505                    lil baby                                 all in
# 77506              lil baby;gunna                          drip too hard
# 77507                        u137                        forever longing
#
#        popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0             100       156943     False        0.7140   0.472    2    -7.375
# 1              99       198937     False        0.6210   0.782    2    -5.548
# 2              98       162637     False        0.8350   0.679    7    -5.329
# 3              98       175238      True        0.5610   0.965    7    -3.673
# 4              97       178567      True        0.9110   0.712    1    -5.105
# ...           ...          ...       ...           ...     ...  ...       ...
# 77503           0       200470      True        0.6430   0.605    4    -5.968
# 77504           0       189147      True        0.9420   0.566   11    -4.834
# 77505           0       156032      True        0.8360   0.649   11    -6.442
# 77506           0       145542      True        0.8970   0.662    1    -6.903
# 77507           0       355200     False        0.0952   0.332    7   -13.901
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0         1       0.0864       0.01300          0.000005    0.2660   0.2380
# 1         1       0.0440       0.01250          0.033000    0.2300   0.5500
# 2         0       0.0364       0.58300          0.000002    0.2180   0.8500
# 3         0       0.0343       0.00383          0.000007    0.3710   0.3040
# 4         0       0.0817       0.09010          0.000027    0.0933   0.4250
# ...     ...          ...           ...               ...       ...      ...
# 77503     0       0.2970       0.03360          0.000000    0.1120   0.1450
# 77504     1       0.2260       0.07730          0.000000    0.1100   0.4790
# 77505     1       0.3320       0.07160          0.000000    0.0943   0.2940
# 77506     0       0.2920       0.08520          0.000000    0.5340   0.3900
# 77507     1       0.0349       0.09680          0.797000    0.3360   0.0653
#
#          tempo  time_signature      genre artist_primary
# 0      131.121               4        pop      sam smith
# 1      128.033               4    hip-hop       bizarrap
# 2      124.980               4  reggaeton  manuel turizo
# 3      128.040               4        edm   david guetta
# 4       92.005               4     reggae      bad bunny
# ...        ...             ...        ...            ...
# 77503   84.216               4    hip-hop       lil baby
# 77504  132.858               4    hip-hop         future
# 77505   95.084               4    hip-hop       lil baby
# 77506  112.509               4    hip-hop       lil baby
# 77507   74.928               4    ambient           u137
#
# [77508 rows x 19 columns]

# %% [markdown]
# Split into a dataframe for clustering and a dataframe containing the metadata

# %%
df.columns.unique()
# Out:
# Index(['artists', 'name', 'popularity', 'duration_ms', 'explicit',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'genre', 'artist_primary'],
#       dtype='object')

# %%
cluster_features = ['danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

df_cluster = df[cluster_features]
df_cluster.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.714   0.472    -7.375       0.0864       0.01300
# 1         0.621   0.782    -5.548       0.0440       0.01250
# 2         0.835   0.679    -5.329       0.0364       0.58300
# 3         0.561   0.965    -3.673       0.0343       0.00383
# 4         0.911   0.712    -5.105       0.0817       0.09010
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000005    0.2660    0.238  131.121
# 1          0.033000    0.2300    0.550  128.033
# 2          0.000002    0.2180    0.850  124.980
# 3          0.000007    0.3710    0.304  128.040
# 4          0.000027    0.0933    0.425   92.005

# %% [markdown]
# These features need to be scaled

# %% [markdown]
# # Engineer Features to Support Hypotheses
#
# H1 Dance–Energy Index (H1)
#
# Purpose:
# Capture “movement intensity” — upbeat dance tracks vs calm ones.

# %%
df_cluster["dance_energy_index"] = (df["danceability"] + df["energy"]) / 2
df_cluster.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.714   0.472    -7.375       0.0864       0.01300
# 1         0.621   0.782    -5.548       0.0440       0.01250
# 2         0.835   0.679    -5.329       0.0364       0.58300
# 3         0.561   0.965    -3.673       0.0343       0.00383
# 4         0.911   0.712    -5.105       0.0817       0.09010
#
#    instrumentalness  liveness  valence    tempo  dance_energy_index
# 0          0.000005    0.2660    0.238  131.121              0.5930
# 1          0.033000    0.2300    0.550  128.033              0.7015
# 2          0.000002    0.2180    0.850  124.980              0.7570
# 3          0.000007    0.3710    0.304  128.040              0.7630
# 4          0.000027    0.0933    0.425   92.005              0.8115

# %% [markdown]
# H2: Acoustic Profile
#
# Purpose:
# Identify acoustic / lo-fi / instrumental-leaning tracks.

# %%
df_cluster["acoustic_profile"] = (df["acousticness"] + df["instrumentalness"]) / 2
df_cluster
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0            0.7140   0.472    -7.375       0.0864       0.01300
# 1            0.6210   0.782    -5.548       0.0440       0.01250
# 2            0.8350   0.679    -5.329       0.0364       0.58300
# 3            0.5610   0.965    -3.673       0.0343       0.00383
# 4            0.9110   0.712    -5.105       0.0817       0.09010
# ...             ...     ...       ...          ...           ...
# 77503        0.6430   0.605    -5.968       0.2970       0.03360
# 77504        0.9420   0.566    -4.834       0.2260       0.07730
# 77505        0.8360   0.649    -6.442       0.3320       0.07160
# 77506        0.8970   0.662    -6.903       0.2920       0.08520
# 77507        0.0952   0.332   -13.901       0.0349       0.09680
#
#        instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0              0.000005    0.2660   0.2380  131.121              0.5930
# 1              0.033000    0.2300   0.5500  128.033              0.7015
# 2              0.000002    0.2180   0.8500  124.980              0.7570
# 3              0.000007    0.3710   0.3040  128.040              0.7630
# 4              0.000027    0.0933   0.4250   92.005              0.8115
# ...                 ...       ...      ...      ...                 ...
# 77503          0.000000    0.1120   0.1450   84.216              0.6240
# 77504          0.000000    0.1100   0.4790  132.858              0.7540
# 77505          0.000000    0.0943   0.2940   95.084              0.7425
# 77506          0.000000    0.5340   0.3900  112.509              0.7795
# 77507          0.797000    0.3360   0.0653   74.928              0.2136
#
#        acoustic_profile
# 0              0.006502
# 1              0.022750
# 2              0.291501
# 3              0.001919
# 4              0.045063
# ...                 ...
# 77503          0.016800
# 77504          0.038650
# 77505          0.035800
# 77506          0.042600
# 77507          0.446900
#
# [77508 rows x 11 columns]

# %% [markdown]
# H4 Mood Index
#
# Purpose:
# Capture emotional feel — sad/calm vs happy/energetic.

# %%
df_cluster["mood_index"] = (df["valence"] + df["energy"]) / 2
df_cluster
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0            0.7140   0.472    -7.375       0.0864       0.01300
# 1            0.6210   0.782    -5.548       0.0440       0.01250
# 2            0.8350   0.679    -5.329       0.0364       0.58300
# 3            0.5610   0.965    -3.673       0.0343       0.00383
# 4            0.9110   0.712    -5.105       0.0817       0.09010
# ...             ...     ...       ...          ...           ...
# 77503        0.6430   0.605    -5.968       0.2970       0.03360
# 77504        0.9420   0.566    -4.834       0.2260       0.07730
# 77505        0.8360   0.649    -6.442       0.3320       0.07160
# 77506        0.8970   0.662    -6.903       0.2920       0.08520
# 77507        0.0952   0.332   -13.901       0.0349       0.09680
#
#        instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0              0.000005    0.2660   0.2380  131.121              0.5930
# 1              0.033000    0.2300   0.5500  128.033              0.7015
# 2              0.000002    0.2180   0.8500  124.980              0.7570
# 3              0.000007    0.3710   0.3040  128.040              0.7630
# 4              0.000027    0.0933   0.4250   92.005              0.8115
# ...                 ...       ...      ...      ...                 ...
# 77503          0.000000    0.1120   0.1450   84.216              0.6240
# 77504          0.000000    0.1100   0.4790  132.858              0.7540
# 77505          0.000000    0.0943   0.2940   95.084              0.7425
# 77506          0.000000    0.5340   0.3900  112.509              0.7795
# 77507          0.797000    0.3360   0.0653   74.928              0.2136
#
#        acoustic_profile  mood_index
# 0              0.006502     0.35500
# 1              0.022750     0.66600
# 2              0.291501     0.76450
# 3              0.001919     0.63450
# 4              0.045063     0.56850
# ...                 ...         ...
# 77503          0.016800     0.37500
# 77504          0.038650     0.52250
# 77505          0.035800     0.47150
# 77506          0.042600     0.52600
# 77507          0.446900     0.19865
#
# [77508 rows x 12 columns]

# %% [markdown]
# H2 and H3:
# Vocal Presence
#
# Purpose:
# Separate instrumental tracks from vocal / rap-heavy tracks.

# %%
df_cluster["vocal_presence"] = 1 - df["instrumentalness"]
df_cluster
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0            0.7140   0.472    -7.375       0.0864       0.01300
# 1            0.6210   0.782    -5.548       0.0440       0.01250
# 2            0.8350   0.679    -5.329       0.0364       0.58300
# 3            0.5610   0.965    -3.673       0.0343       0.00383
# 4            0.9110   0.712    -5.105       0.0817       0.09010
# ...             ...     ...       ...          ...           ...
# 77503        0.6430   0.605    -5.968       0.2970       0.03360
# 77504        0.9420   0.566    -4.834       0.2260       0.07730
# 77505        0.8360   0.649    -6.442       0.3320       0.07160
# 77506        0.8970   0.662    -6.903       0.2920       0.08520
# 77507        0.0952   0.332   -13.901       0.0349       0.09680
#
#        instrumentalness  liveness  valence    tempo  dance_energy_index  \
# 0              0.000005    0.2660   0.2380  131.121              0.5930
# 1              0.033000    0.2300   0.5500  128.033              0.7015
# 2              0.000002    0.2180   0.8500  124.980              0.7570
# 3              0.000007    0.3710   0.3040  128.040              0.7630
# 4              0.000027    0.0933   0.4250   92.005              0.8115
# ...                 ...       ...      ...      ...                 ...
# 77503          0.000000    0.1120   0.1450   84.216              0.6240
# 77504          0.000000    0.1100   0.4790  132.858              0.7540
# 77505          0.000000    0.0943   0.2940   95.084              0.7425
# 77506          0.000000    0.5340   0.3900  112.509              0.7795
# 77507          0.797000    0.3360   0.0653   74.928              0.2136
#
#        acoustic_profile  mood_index  vocal_presence
# 0              0.006502     0.35500        0.999995
# 1              0.022750     0.66600        0.967000
# 2              0.291501     0.76450        0.999998
# 3              0.001919     0.63450        0.999993
# 4              0.045063     0.56850        0.999973
# ...                 ...         ...             ...
# 77503          0.016800     0.37500        1.000000
# 77504          0.038650     0.52250        1.000000
# 77505          0.035800     0.47150        1.000000
# 77506          0.042600     0.52600        1.000000
# 77507          0.446900     0.19865        0.203000
#
# [77508 rows x 13 columns]

# %% [markdown]
# We have engineered features that represent movement, mood, acoustic character, and vocal presence to support similarity-based clustering

# %%
df_cluster.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  77508.000000  77508.000000  77508.000000  77508.000000  77508.000000
# mean       0.558231      0.633894     -8.619441      0.089621      0.332315
# std        0.177990      0.259328      5.333961      0.118077      0.340301
# min        0.000000      0.000000    -49.531000      0.000000      0.000000
# 25%        0.445000      0.453000    -10.488250      0.036100      0.016300
# 50%        0.572000      0.676000     -7.273000      0.049200      0.196000
# 75%        0.689000      0.856000     -5.141000      0.087700      0.634000
# max        0.985000      1.000000      4.532000      0.965000      0.996000
#
#        instrumentalness      liveness       valence         tempo  \
# count      77508.000000  77508.000000  77508.000000  77508.000000
# mean           0.185649      0.218597      0.463641    122.076398
# std            0.332705      0.196464      0.264001     30.242541
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.098600      0.241000     99.010000
# 50%            0.000085      0.133000      0.449000    122.002000
# 75%            0.154000      0.281000      0.677000    140.184250
# max            1.000000      1.000000      0.995000    243.372000
#
#        dance_energy_index  acoustic_profile    mood_index  vocal_presence
# count        77508.000000      77508.000000  77508.000000    77508.000000
# mean             0.596063          0.258982      0.548767        0.814351
# std              0.166546          0.249551      0.207338        0.332705
# min              0.000000          0.000000      0.000000        0.000000
# 25%              0.507000          0.039901      0.413000        0.846000
# 50%              0.632000          0.202500      0.567000        0.999915
# 75%              0.717500          0.408501      0.705500        1.000000
# max              0.978000          0.997500      0.986000        1.000000

# %% [markdown]
# # Create dataframe of metadata

# %%
metadata_cols = ['artists', 'name', 'popularity', 'duration_ms', 'explicit', 'genre']

df_metadata = df[metadata_cols]
df_metadata.head()
# Out:
#                       artists                                   name  \
# 0        sam smith;kim petras                                 unholy
# 1            bizarrap;quevedo  quevedo: bzrp music sessions, vol. 52
# 2               manuel turizo                             la bachata
# 3     david guetta;bebe rexha                               i'm good
# 4  bad bunny;chencho corleone                        me porto bonito
#
#    popularity  duration_ms  explicit      genre
# 0         100       156943     False        pop
# 1          99       198937     False    hip-hop
# 2          98       162637     False  reggaeton
# 3          98       175238      True        edm
# 4          97       178567      True     reggae

# %%
df_cluster.to_csv(f'{PROJECT_ROOT}/data/engineered/spotify_features.csv', index=False)
